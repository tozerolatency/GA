# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a serious of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
#movies.to_csv('file')
#movies_new = pd.read_csv('file',encoding='utf-8')
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
movies.actors_list = movies.actors_list.str.replace("u'", "'")
movies.actors_list
# Out:
# 0        ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# 1           ['Marlon Brando', 'Al Pacino', 'James Caan']
# 2       ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# 3      ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# 4      ['John Travolta', 'Uma Thurman', 'Samuel L. Ja...
# 5        ['Henry Fonda', 'Lee J. Cobb', 'Martin Balsam']
# 6      ['Clint Eastwood', 'Eli Wallach', 'Lee Van Cle...
# 7      ['Elijah Wood', 'Viggo Mortensen', 'Ian McKell...
# 8       ['Liam Neeson', 'Ralph Fiennes', 'Ben Kingsley']
# 9      ['Brad Pitt', 'Edward Norton', 'Helena Bonham ...
# 10      ['Elijah Wood', 'Ian McKellen', 'Orlando Bloom']
# 11     ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', ...
# 12     ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher']
# 13          ['Tom Hanks', 'Robin Wright', 'Gary Sinise']
# 14     ['Elijah Wood', 'Ian McKellen', 'Viggo Mortens...
# 15     ['Matthew McConaughey', 'Anne Hathaway', 'Jess...
# ...

# %% [markdown]
# #### Check the number of rows and columns.

# %%
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# #### Check the data type of each column.

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
movies.duration.mean()
# Out:
# 120.97957099080695

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
movies.duration.sort_values(ascending=True)
movies.sort_values(['duration'])
# Out:
#      star_rating                                          title  \
# 389          8.0                                         Freaks
# 338          8.0                            Battleship Potemkin
# 258          8.1                    The Cabinet of Dr. Caligari
# 293          8.1                                      Duck Soup
# 88           8.4                                        The Kid
# 742          7.6                                      Following
# 351          8.0                                   Frankenstein
# 938          7.4                            Alice in Wonderland
# 405          7.9                      The Bride of Frankenstein
# 303          8.0                 The Nightmare Before Christmas
# 713          7.6                                The Jungle Book
# 864          7.5                                          [Rec]
# 489          7.8                     The Triplets of Belleville
# 535          7.8                                          Zelig
# ...

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
movies.hist(column=['duration'],bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111ea2898>]], dtype=object)

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
movies.boxplot(column=['duration'])

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
movies.groupby(['content_rating'])['title'].count()
# Out:
# content_rating
# APPROVED      47
# G             32
# GP             3
# NC-17          7
# NOT RATED     65
# PASSED         7
# PG           123
# PG-13        189
# R            460
# TV-MA          1
# UNRATED       38
# X              4
# Name: title, dtype: int64

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
data = movies.groupby(['content_rating'])['title'].count().reset_index()


data.plot(kind='bar', x='content_rating',y='title', title='no of movies by context_ratings',figsize=(10,5))

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
# Answer:

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
short_movies = movies[movies.duration <= 120]
long_movies = movies[movies.duration >= 120]

print (short_movies.star_rating.mean())
print (long_movies.star_rating.mean())
# Out:
# 7.8384898710865345
# 7.948898678414082

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
movies.groupby(['genre'])['duration'].mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
movies.groupby(['genre']).head(1)
# Out:
#      star_rating                                          title  \
# 0            9.3                       The Shawshank Redemption
# 3            9.0                                The Dark Knight
# 5            8.9                                   12 Angry Men
# 6            8.9                 The Good, the Bad and the Ugly
# 7            8.9  The Lord of the Rings: The Return of the King
# 8            8.9                               Schindler's List
# 25           8.6                              Life Is Beautiful
# 30           8.6                                  Spirited Away
# 38           8.6                                    Rear Window
# 39           8.6                                         Psycho
# 105          8.3                                  The Third Man
# 145          8.2                                   Blade Runner
# 338          8.0                            Battleship Potemkin
# 350          8.0                              Shadow of a Doubt
# ...

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
movies[movies.duplicated(subset='title',keep=False)]
# Out:
#      star_rating                            title content_rating      genre  \
# 466          7.9  The Girl with the Dragon Tattoo              R      Crime
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 662          7.7                        True Grit          PG-13  Adventure
# 678          7.7                   Les Miserables          PG-13      Drama
# 703          7.6                          Dracula       APPROVED     Horror
# 905          7.5                          Dracula              R     Horror
# 924          7.5                   Les Miserables          PG-13      Crime
# 936          7.4                        True Grit            NaN  Adventure
#
#      duration                                        actors_list
# 466       158  ['Daniel Craig', 'Rooney Mara', 'Christopher P...
# 482       152  ['Michael Nyqvist', 'Noomi Rapace', 'Ewa Fr\xf...
# 662       110  ['Jeff Bridges', 'Matt Damon', 'Hailee Steinfe...
# ...

# %%
duplicated = movies[movies.duplicated(subset='title',keep=False)]
duplicated.sort_values(by=['title'])
# Out:
#      star_rating                            title content_rating      genre  \
# 703          7.6                          Dracula       APPROVED     Horror
# 905          7.5                          Dracula              R     Horror
# 678          7.7                   Les Miserables          PG-13      Drama
# 924          7.5                   Les Miserables          PG-13      Crime
# 466          7.9  The Girl with the Dragon Tattoo              R      Crime
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 662          7.7                        True Grit          PG-13  Adventure
# 936          7.4                        True Grit            NaN  Adventure
#
#      duration                                        actors_list
# 703        85  ['Bela Lugosi', 'Helen Chandler', 'David Manne...
# 905       128  ['Gary Oldman', 'Winona Ryder', 'Anthony Hopki...
# 678       158  ['Hugh Jackman', 'Russell Crowe', 'Anne Hathaw...
# ...

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
# Answer:

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# Answer:

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!
